# %% [markdown]
# ### Hybrid Vector datasource for Advanced Retrieval

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance, PayloadSchemaType, PointStruct, SparseVectorParams, Document, Prefetch, FusionQuery
from qdrant_client.http.models import models
import pandas as pd
import openai
import fastembed

# %% [markdown]
# ### create hybrid collection

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

### create collection
collection_name = "amazon_items-collection-hybrid-02"

qdrant_client.create_collection(
    collection_name=collection_name,
    vectors_config = {
        "text-embedding-3-small": VectorParams(size=1536, distance=Distance.COSINE)
    },
    sparse_vectors_config = {
        "bm25": SparseVectorParams(modifier=models.Modifier.IDF)
    }
)

# %%
qdrant_client.create_payload_index(
    collection_name="amazon_items-collection-hybrid-02",
    field_name="parent_asin",
    field_schema=PayloadSchemaType.KEYWORD
)

# %%
def get_embeddings_batch(text_list, model="text-embedding-3-small", batch_size=100):
    """
    Get embeddings for a list of text using a specified model.
    
    Args:
        text_list (list): List of text strings to embed.
    """
    
    if len(text_list) <= batch_size:
        response = openai.embeddings.create(
            model=model,
            input=text_list
        )
        return [item.embedding for item in response.data]
    
    all_embeddings = []
    counter = 1
    for i in range(0, len(text_list), batch_size):
        batch = text_list[i:i+batch_size]
        response = openai.embeddings.create(
            model=model,
            input=batch
        )
        all_embeddings.extend([item.embedding for item in response.data])
        print(f"Processed {counter * batch_size} out of {len(text_list)}")
        counter += 1
    
    return all_embeddings

# %%
df_items = pd.read_json("../../data/meta_Electronics_2022_onwards_with_ratings_100_sample_1000.jsonl", lines=True)

# %%
df_items.head()
len(df_items)

# %%
def combine_description_and_title(row):
    return f"{row['title']} {row['description']}"
df_items['description'] = df_items.apply(combine_description_and_title, axis=1)

# %%
def extract_first_large_image(row):
    return row['images'][0].get("large", "")
df_items['image'] = df_items.apply(extract_first_large_image, axis=1)

# %%
data_to_embed = df_items[['description', 'image', "rating_number", "price", "average_rating", "parent_asin"]].to_dict(orient="records")

# %%
text_to_embed = [item['description'] for item in data_to_embed]

# %%
embeddings = get_embeddings_batch(text_to_embed)

# %%
len(embeddings)

# %%
pointsstructs = []
i = 1
for embedding, data in zip(embeddings, data_to_embed):
    pointsstructs.append(
        PointStruct(
            id=i,
            vector= { 
                     "text-embedding-3-small": embedding,
                     "bm25": Document(text=data["description"], model="Qdrant/bm25")
            },
            payload=data
    ))
    i += 1

# %%
pointsstructs[0].vector.get("bm25")

# %% [markdown]
# ### Load into new hybrid collection

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

qdrant_client.upsert(
    collection_name="amazon_items-collection-hybrid-02",
    points=pointsstructs[0:500],
    wait=True
)

# %%
qdrant_client.upsert(
    collection_name="amazon_items-collection-hybrid-02",
    points=pointsstructs[500:],
    wait=True
)

# %% [markdown]
# ### Perform hybrid-search

# %%
from qdrant_client import QdrantClient
import openai
import instructor
instructor_prompt = instructor.from_openai(openai.OpenAI())

def create_embeddings(text, model="text-embedding-3-small"):
   
    response = openai.embeddings.create(
        model=model,
        input=text
    )
        
    return response.data[0].embedding

def retrieve_embedding_data(qd_client: QdrantClient, query, collection_name, k=5):
    querry_embeddings = create_embeddings(query)
    response = qd_client.query_points(
        collection_name=collection_name,
        prefetch=[Prefetch(
            query=querry_embeddings,
            using="text-embedding-3-small",
            limit=20),
            Prefetch(
                query=Document(text=query, model="Qdrant/bm25"),
                using="bm25",
                limit=20)
            ],
        query=querry_embeddings,
        limit=k,
    )
    retrieved_context_ids = []
    retrieved_context = []
    retrieved_scores = []
    retrieved_context_ratings = []
    
    for point in response.points:
        retrieved_context_ids.append(point.payload["parent_asin"])
        retrieved_context.append(point.payload["description"])
        retrieved_scores.append(point.score)
        retrieved_context_ratings.append(point.payload["average_rating"])

    # return dictionary of retrieved data
    return {
        "context_ids": retrieved_context_ids,
        "context": retrieved_context,
        "scores": retrieved_scores,
        "context_ratings": retrieved_context_ratings
    }

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")
sample_query = "top laptop under 1000$"
retrieved_data = retrieve_embedding_data(qdrant_client, sample_query, "amazon_items-collection-hybrid-02", 5)
retrieved_data
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[7], line 3
#       1 qdrant_client = QdrantClient(url="http://localhost:6333")
#       2 sample_query = "top laptop under 1000$"
# ----> 3 retrieved_data = retrieve_embedding_data(qdrant_client, sample_query, "amazon_items-collection-hybrid-02", 5)
#       4 retrieved_data
#
# Cell In[3], line 17, in retrieve_embedding_data(qd_client, query, collection_name, k)
#      15 def retrieve_embedding_data(qd_client: QdrantClient, query, collection_name, k=5):
#      16     querry_embeddings = create_embeddings(query)
# ---> 17     response = qd_client.query_points(
#      18         collection_name=collection_name,
#      19         prefetch=[Prefetch(
#      20             query=querry_embeddings,
#      21             using="text-embedding-3-small",
#      22             limit=20),
#      23             Prefetch(
#      24                 query=Document(text=query, model="Qdrant/bm25"),
#      25                 using="bm25",
#      26                 limit=20)
#      27             ],
#      28         query=querry_embeddings,
#      29         limit=k,
#      30     )
#      31     retrieved_context_ids = []
#      32     retrieved_context = []
#
# File ~/repos/ai-agent-bootcamp-prerequisites/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:423, in QdrantClient.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     408         else:
#     409             prefetch = (
#     410                 next(
#     411                     iter(
#    (...)    420                 else None
#     421             )
# --> 423 return self._client.query_points(
#     424     collection_name=collection_name,
#     425     query=query,
#     426     prefetch=prefetch,
#     427     query_filter=query_filter,
#     428     search_params=search_params,
#     429     limit=limit,
#     430     offset=offset,
#     431     with_payload=with_payload,
#     432     with_vectors=with_vectors,
#     433     score_threshold=score_threshold,
#     434     using=using,
#     435     lookup_from=lookup_from,
#     436     consistency=consistency,
#     437     shard_key_selector=shard_key_selector,
#     438     timeout=timeout,
#     439     **kwargs,
#     440 )
#
# File ~/repos/ai-agent-bootcamp-prerequisites/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:538, in QdrantRemote.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     521     lookup_from = GrpcToRest.convert_lookup_location(lookup_from)
#     523 query_request = models.QueryRequest(
#     524     shard_key=shard_key_selector,
#     525     prefetch=prefetch,
#    (...)    535     lookup_from=lookup_from,
#     536 )
# --> 538 query_result = self.http.search_api.query_points(
#     539     collection_name=collection_name,
#     540     consistency=consistency,
#     541     timeout=timeout,
#     542     query_request=query_request,
#     543 )
#     545 result: models.QueryResponse | None = query_result.result
#     546 assert result is not None, "Search returned None"
#
# File ~/repos/ai-agent-bootcamp-prerequisites/.venv/lib/python3.12/site-packages/qdrant_client/http/api/search_api.py:783, in SyncSearchApi.query_points(self, collection_name, consistency, timeout, query_request)
#     773 def query_points(
#     774     self,
#     775     collection_name: str,
#    (...)    778     query_request: m.QueryRequest = None,
#     779 ) -> m.InlineResponse20021:
#     780     """
#     781     Universally query points. This endpoint covers all capabilities of search, recommend, discover, filters. But also enables hybrid and multi-stage queries.
#     782     """
# --> 783     return self._build_for_query_points(
#     784         collection_name=collection_name,
#     785         consistency=consistency,
#     786         timeout=timeout,
#     787         query_request=query_request,
#     788     )
#
# File ~/repos/ai-agent-bootcamp-prerequisites/.venv/lib/python3.12/site-packages/qdrant_client/http/api/search_api.py:181, in _SearchApi._build_for_query_points(self, collection_name, consistency, timeout, query_request)
#     179 if "Content-Type" not in headers:
#     180     headers["Content-Type"] = "application/json"
# --> 181 return self.api_client.request(
#     182     type_=m.InlineResponse20021,
#     183     method="POST",
#     184     url="/collections/{collection_name}/points/query",
#     185     headers=headers if headers else None,
#     186     path_params=path_params,
#     187     params=query_params,
#     188     content=body,
#     189 )
#
# File ~/repos/ai-agent-bootcamp-prerequisites/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/repos/ai-agent-bootcamp-prerequisites/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Wrong input: Not existing vector name error: "},"time":0.0746945}'
